# %% [markdown]
# # Model Visualization Through the FINN Flow
# This notebook will visualize the network from each stage from finn_export through PYNQ bitfile synthesis.

# %%
from finn.util.visualization import showInNetron as sin

# %% [markdown]
# ## Post Export

# %%
sin("quant_models/facileV3_6b_1.onnx")
# Out:
# Serving 'quant_models/facileV3_6b_1.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Post Cleanup
# The network is cleaned up before synthesis using the build dataflow tool

# %%
sin("quant_models/facileV3_6b_1_tidy.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'quant_models/facileV3_6b_1_tidy.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## build_dataflow_config Steps
# The rest of these networks are generated by the build_dataflow_config tool.

# %%
sin("output_final/intermediate_models/1_step_tidy_up.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/1_step_tidy_up.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/2_step_streamline.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/2_step_streamline.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/3_step_convert_to_hls.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/3_step_convert_to_hls.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/4_step_create_dataflow_partition.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/4_step_create_dataflow_partition.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/5_step_target_fps_parallelization.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/5_step_target_fps_parallelization.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/6_step_apply_folding_config.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/6_step_apply_folding_config.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/7_step_generate_estimate_reports.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/7_step_generate_estimate_reports.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/8_step_hls_ipgen.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/8_step_hls_ipgen.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/9_step_set_fifo_depths.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/9_step_set_fifo_depths.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/10_step_create_stitched_ip.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/10_step_create_stitched_ip.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/11_step_measure_rtlsim_performance.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/11_step_measure_rtlsim_performance.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/12_step_make_pynq_driver.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/12_step_make_pynq_driver.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/13_step_out_of_context_synthesis.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/13_step_out_of_context_synthesis.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/14_step_synthesize_bitfile.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/14_step_synthesize_bitfile.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/15_step_deployment_package.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/15_step_deployment_package.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
sin("output_final/intermediate_models/dataflow_parent.onnx")
# Out:
# Stopping http://0.0.0.0:8081
# Serving 'output_final/intermediate_models/dataflow_parent.onnx' at http://0.0.0.0:8081
#         <iframe
#             width="100%"
#             height="400"
#             src="http://0.0.0.0:8081/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
